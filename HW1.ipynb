# %% [markdown]
# <a href="https://colab.research.google.com/github/chutimabo-ctrl/DW_lab_6730202485/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('ID6730202485')
# Out:
# ID6730202485
